# %% [markdown]
# Source:
#
# https://www.youtube.com/watch?v=UmljXZIypDc&list=PL-osiE80TeTtoQCKZ03TU5fNfx2UY6U4p
#
# Source code:
#
# https://github.com/CoreyMSchafer/code_snippets/tree/master/Django_Blog

# %%
# Structure
'''
├── Notes.ipynb
├── django_project
│ ├── __init__.py
│ ├── asgi.py
│ ├── settings.py
│ ├── urls.py
│ └── wsgi.py
└── manage.py
'''
# start the development server
! python manage.py runserver

# Install the app in the mysite/settings.py
# This will create relevant tables in the db.sqlite3 database file
! python manage.py migrate

# create a new app
! python manage.py startapp blog
'''
── blog
│   ├── __init__.py
│   ├── admin.py
│   ├── apps.py
│   ├── migrations
│   │   └── __init__.py
│   ├── models.py
│   ├── tests.py
│   └── views.py
├── db.sqlite3
├── django_project
│   ├── __init__.py
│   ├── __pycache__
│   │   ├── __init__.cpython-313.pyc
│   │   ├── settings.cpython-313.pyc
│   │   ├── urls.cpython-313.pyc
│   │   └── wsgi.cpython-313.pyc
│   ├── asgi.py
│   ├── settings.py
│   ├── urls.py
│   └── wsgi.py
├── manage.py
└── Notes.ipynb
'''


# Get a list of all available commands
! django-admin


'''
To create a new app:

1. python manage.py startapp blog.
2. in blog/views.py, define a view function called index that returns an HttpResponse.
3. in blog/urls.py, create a URL pattern for the index view (home page) of the blog app.
4. in mysite/urls.py, include the URL patterns defined in blog/urls.py.
5. create blog/models.py and define the structure of your database tables.
6. add "blog.apps.BlogConfig", to the INSTALLED_APPS list in mysite/settings.py.
7. python manage.py makemigrations blog: create migration files for the blog app.
8. python manage.py sqlmigrate blog 0001: see the SQL statements that will be executed for the first migration of the blog app.
9. python manage.py migrate: apply the migrations to the database, creating the necessary tables for the blog app.
10. python manage.py shell: open the Django shell to interact with the database and test your models.
11. python manage.py createsuperuser: create a superuser account to access the Django admin interface.
12. open the blog/admin.py file and register the Question model to make it accessible in the admin interface.
'''

# ORM -> Object Relational Mapping
# Create models in blog/models.py to define the structure of your database tables.

# Django package for handling forms in a more elegant way, especially when using Bootstrap for styling.
! pip install django-crispy-forms
! pip install crispy_bootstrap5
