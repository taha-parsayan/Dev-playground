# %% [markdown]
# # Source:
#
# https://docs.djangoproject.com/en/6.0/intro/tutorial01/

# %%
# check if django is installed
! python -m django --version
# Out:
# 6.0.2

# %%
# start a new django project named "mysite" in the "DJANGO" directory
! django-admin startproject mysite DJANGO

'''
DJANGO/
    manage.py
    mysite/
        __init__.py
        settings.py
        urls.py
        asgi.py
        wsgi.py
'''
